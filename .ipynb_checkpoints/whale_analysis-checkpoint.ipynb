# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P TSX 60 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp_tsx_history.csv`: Contains historical closing prices of the S&P TSX 60 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data.

# %%
whale_portfolio_path = Path("./whale_returns.csv") # Set the path of the CSV files

# %%
# Reading whale returns
whale_portfolio = pd.read_csv(whale_portfolio_path, parse_dates=True, infer_datetime_format=True)

# %%
# Count nulls
whale_portfolio.isnull().sum()
# Out:
# Date                           0
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_portfolio = whale_portfolio.dropna().copy()

# %%
whale_portfolio['Date'] = pd.to_datetime(whale_portfolio['Date'])

# %%
whale_portfolio = whale_portfolio.set_index('Date')

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data.

# %%
# Reading algorithmic returns
algorithmic_portfolio_path = Path("./algo_returns.csv") # Set the path of the CSV files
algorithmic_portfolio = pd.read_csv(algorithmic_portfolio_path, parse_dates=True, infer_datetime_format=True)

# %%
# Count nulls
algorithmic_portfolio.isnull().sum()
# Out:
# Date      0
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algorithmic_portfolio = algorithmic_portfolio.dropna().copy()

# %%
algorithmic_portfolio['Date'] = pd.to_datetime(algorithmic_portfolio['Date'])
algorithmic_portfolio = algorithmic_portfolio.set_index('Date')

# %%
algorithmic_portfolio.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P TSX 60 Returns
#
# Read the S&P TSX 60 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_portfolio_path = Path("./sp_tsx_history.csv") # Set the path of the CSV files
sp_portfolio = pd.read_csv(sp_portfolio_path, parse_dates=True, infer_datetime_format=True)

# %%
# Check Data Types
sp_portfolio.dtypes
# Out:
# Date     object
# Close    object
# dtype: object

# %%
sp_portfolio.head()
# Out:
#          Date       Close
# 0  1-Oct-2012  $12,370.19
# 1  2-Oct-2012  $12,391.23
# 2  3-Oct-2012  $12,359.47
# 3  4-Oct-2012  $12,447.68
# 4  5-Oct-2012  $12,418.99

# %%
# Fix Data Types
sp_portfolio['Date'] = pd.to_datetime(sp_portfolio['Date'])
sp_portfolio["Close"] = sp_portfolio["Close"].str.replace("$", "").str.replace(",", "").astype(float)
# Out:
# C:\Users\Viktoriya\anaconda32\envs\dev\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
sp_portfolio.dtypes
# Out:
# Date     datetime64[ns]
# Close           float64
# dtype: object

# %%
sp_portfolio.head()
# Out:
#         Date     Close
# 0 2012-10-01  12370.19
# 1 2012-10-02  12391.23
# 2 2012-10-03  12359.47
# 3 2012-10-04  12447.68
# 4 2012-10-05  12418.99

# %%
sp_portfolio = sp_portfolio.set_index('Date')

# %%
# Calculate Daily Returns
sp_portfolio = sp_portfolio.pct_change().dropna().copy()
sp_portfolio.head()
# Out:
#                Close
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %%
# Drop nulls

# %%
# Rename `Close` Column to be specific to this portfolio.
sp_portfolio = sp_portfolio.rename(columns={'Close': 'S&P'})

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P TSX 60 Returns

# %%
whale_portfolio.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P TSX 60 Returns into a single DataFrame with columns for each portfolio's returns.
all_returns = pd.concat([whale_portfolio, algorithmic_portfolio, sp_portfolio], axis="columns", join="inner")
all_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2       S&P
# Date
# 2015-03-03 -0.000949 -0.008530
# 2015-03-04  0.002416 -0.003371
# 2015-03-05  0.004323  0.001344
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
all_returns.plot(figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
comul_returns = (1+all_returns).cumprod()

# Plot cumulative returns
comul_returns.plot(figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios.
# 4. Determine which portfolios are riskier than the S&P TSX 60.
# 5. Calculate the Annualized Standard Deviation.

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
all_returns.plot.box(figsize=(20, 10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
all_portfolio_std = all_returns.std()
all_portfolio_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# S&P                            0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P TSX 60

# %%
# Calculate  the daily standard deviation of S&P TSX 60
sp_std = all_portfolio_std['S&P']
# Determine which portfolios are riskier than the S&P TSX 60
all_portfolio_std[all_portfolio_std > sp_std]
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = all_portfolio_std * np.sqrt(252)
annualized_std.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# S&P                            0.111664
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window.
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P TSX 60.
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta for it and the S&P TSX 60.

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
all_portfolio_std_rolling = all_returns.rolling(window=21).std()
# Plot the rolling standard deviation
all_portfolio_std_rolling.plot(figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = all_returns.corr()
# Display de correlation matrix
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 60 TSX

# %%
# Calculate covariance of a single portfolio
covariance = all_returns['Algo 1'].cov(all_returns['S&P'])
# Calculate variance of S&P TSX
variance = all_returns['S&P'].var()
# Computing beta
beta = covariance / variance
print(f"Algo 1 beta: {beta}")
# Plot beta trend
rolling_covariance = all_returns['Algo 1'].rolling(window=60).cov(all_returns['S&P'])
rolling_variance = all_returns['S&P'].rolling(window=60).var()
rolling_beta = rolling_covariance / rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of Algorithm 1 portfolio')
# Out:
# Algo 1 beta: 0.33474459081856844
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of Algorithm 1 portfolio'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
ewa_df = all_returns.ewm(halflife=21,min_periods=1,adjust=True,ignore_na=False,axis=0).std()
ewa_df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = (all_returns.mean() * 252) / (all_returns.std() * np.sqrt(252))
sharpe_ratios.head(10)
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# S&P                            0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P TSX 60) and the whales portfolios.
#
# Algorithmic strategies outperformed S&P. The strategy Algo 1 outperformed other portfolios too, Algo 1 strategy outperformed other strategies except for Berkshire Hathaway.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P TSX 60.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock.
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns.
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others.
# 5. Include correlation analysis to determine which stocks (if any) are correlated.

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
soxx_data = Path('SOXX.csv')
soxx_df = pd.read_csv(soxx_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
soxx_df = soxx_df.rename(columns={'Close':'SOXX'})
soxx_df.head()
# Out:
#                       SOXX
# Date
# 2015-03-03 16:00:00  97.68
# 2015-03-04 16:00:00  97.55
# 2015-03-05 16:00:00  97.61
# 2015-03-06 16:00:00  96.60
# 2015-03-09 16:00:00  96.90

# %%
# Reading data from 2nd stock
amzn_data = Path('AMZN.csv')
amzn_df = pd.read_csv(amzn_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
amzn_df = amzn_df.rename(columns={'Close':'AMZN'})
amzn_df.head()
# Out:
#                       AMZN
# Date
# 2015-03-03 16:00:00  19.23
# 2015-03-04 16:00:00  19.14
# 2015-03-05 16:00:00  19.39
# 2015-03-06 16:00:00  19.00
# 2015-03-09 16:00:00  18.93

# %%
# Reading data from 3rd stock
ko_data = Path('KO.csv')
ko_df = pd.read_csv(amzn_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
ko_df = ko_df.rename(columns={'Close':'KO'})
ko_df.head()
# Out:
#                         KO
# Date
# 2015-03-03 16:00:00  19.23
# 2015-03-04 16:00:00  19.14
# 2015-03-05 16:00:00  19.39
# 2015-03-06 16:00:00  19.00
# 2015-03-09 16:00:00  18.93

# %%
# Combine all stocks in a single DataFrame
my_portfolio_df = pd.concat([soxx_df, amzn_df, ko_df], axis="columns", join="inner")

# %%
my_portfolio_df.index = pd.to_datetime(my_portfolio_df.index).normalize()
my_portfolio_df.head()
# Out:
#              SOXX   AMZN     KO
# Date
# 2015-03-03  97.68  19.23  19.23
# 2015-03-04  97.55  19.14  19.14
# 2015-03-05  97.61  19.39  19.39
# 2015-03-06  96.60  19.00  19.00
# 2015-03-09  96.90  18.93  18.93

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol

# %%
# Calculate daily returns
my_portfolio_returns = my_portfolio_df.pct_change()
# Drop NAs
my_portfolio_returns = my_portfolio_returns.dropna()
# Display sample data
my_portfolio_returns.head()
# Out:
#                 SOXX      AMZN        KO
# Date
# 2015-03-04 -0.001331 -0.004680 -0.004680
# 2015-03-05  0.000615  0.013062  0.013062
# 2015-03-06 -0.010347 -0.020113 -0.020113
# 2015-03-09  0.003106 -0.003684 -0.003684
# 2015-03-10 -0.018473 -0.023772 -0.023772

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
my_portfolio_total_returns = my_portfolio_returns.dot(weights)
# Display sample data
my_portfolio_total_returns.name = 'My portfolio'
my_portfolio_total_returns.head()
# Out:
# Date
# 2015-03-04   -0.003564
# 2015-03-05    0.008913
# 2015-03-06   -0.016858
# 2015-03-09   -0.001421
# 2015-03-10   -0.022005
# Name: My portfolio, dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
joined_portfolio = pd.concat([my_portfolio_total_returns, all_returns], axis="columns", join="inner")
joined_portfolio.head()
# Out:
#             My portfolio  SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-04     -0.003564                   0.002230            0.003241
# 2015-03-05      0.008913                   0.004016            0.004076
# 2015-03-06     -0.016858                  -0.007905           -0.003574
# 2015-03-09     -0.001421                   0.000582            0.004225
# 2015-03-10     -0.022005                  -0.010263           -0.005341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# 2015-03-10                    -0.012079               -0.009739 -0.001392
#
#               Algo 2       S&P
# Date
# 2015-03-04  0.002416 -0.003371
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
joined_annualized_std = joined_portfolio.std() * np.sqrt(252)
joined_annualized_std.head(10)
# Out:
# My portfolio                   0.245564
# SOROS FUND MANAGEMENT LLC      0.124343
# PAULSON & CO.INC.              0.110923
# TIGER GLOBAL MANAGEMENT LLC    0.172883
# BERKSHIRE HATHAWAY INC         0.203727
# Algo 1                         0.120580
# Algo 2                         0.132251
# S&P                            0.111666
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
joined_portfolio_std_rolling = joined_portfolio.rolling(window=21).std() 
# Plot rolling standard deviation
joined_portfolio_std_rolling.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation = joined_portfolio.corr()
sns.heatmap(correlation, vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot the 60-day Rolling Beta for Your Portfolio compared to the S&P 60 TSX

# %%
# Calculate and plot Beta
# Calculate covariance of a single portfolio
joined_covariance = joined_portfolio['My portfolio'].cov(all_returns['S&P'])
# Calculate variance of S&P TSX
joined_variance = joined_portfolio['S&P'].var()
# Computing beta
joined_beta = joined_covariance / joined_variance
# Plot beta trend
joined_rolling_covariance = joined_portfolio['My portfolio'].rolling(window=60).cov(joined_portfolio['S&P'])
joined_rolling_variance = joined_portfolio['S&P'].rolling(window=60).var()
joined_rolling_beta = joined_rolling_covariance / joined_rolling_variance
joined_rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta of My portfolio')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of My portfolio'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
joined_sharpe_ratios = (joined_portfolio.mean() * 252) / (joined_portfolio.std() * np.sqrt(252))
joined_sharpe_ratios.head(10)
# Out:
# My portfolio                   1.334714
# SOROS FUND MANAGEMENT LLC      0.301110
# PAULSON & CO.INC.             -0.534272
# TIGER GLOBAL MANAGEMENT LLC   -0.132665
# BERKSHIRE HATHAWAY INC         0.485005
# Algo 1                         1.496819
# Algo 2                         0.412780
# S&P                            0.225006
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
joined_sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
My portfolio came up quite volatile, but the high Sharpe ratio shows that high profits justify the risk.
